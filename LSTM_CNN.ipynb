# %%
# univariate cnn lstm example
from numpy import array
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import TimeDistributed
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D

# split a univariate sequence into samples
def split_sequence(sequence, n_steps):
	X, y = list(), list()
	for i in range(len(sequence)):
		# find the end of this pattern
		end_ix = i + n_steps
		# check if we are beyond the sequence
		if end_ix > len(sequence)-1:
			break
		# gather input and output parts of the pattern
		seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
		X.append(seq_x)
		y.append(seq_y)
	return array(X), array(y)

# define input sequence
raw_seq = [10, 20, 30, 40, 50, 60, 70, 80, 90]
# choose a number of time steps
n_steps = 4
# split into samples
X, y = split_sequence(raw_seq, n_steps)
# reshape from [samples, timesteps] into [samples, subsequences, timesteps, features]
n_features = 1
n_seq = 2
n_steps = 2
X = X.reshape((X.shape[0], n_seq, n_steps, n_features))
# define model
model = Sequential()
model.add(TimeDistributed(Conv1D(filters=64, kernel_size=1, activation='relu'), input_shape=(None, n_steps, n_features)))
model.add(TimeDistributed(MaxPooling1D(pool_size=2)))
model.add(TimeDistributed(Flatten()))
model.add(LSTM(50, activation='relu'))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')
# fit model
model.fit(X, y, epochs=100, verbose=2)
# Out:
# Epoch 1/100
# 1/1 - 1s - loss: 5094.9570 - 1s/epoch - 1s/step
# Epoch 2/100
# 1/1 - 0s - loss: 5002.4917 - 9ms/epoch - 9ms/step
# Epoch 3/100
# 1/1 - 0s - loss: 4915.1592 - 5ms/epoch - 5ms/step
# Epoch 4/100
# 1/1 - 0s - loss: 4830.1489 - 5ms/epoch - 5ms/step
# Epoch 5/100
# 1/1 - 0s - loss: 4752.6265 - 7ms/epoch - 7ms/step
# Epoch 6/100
# 1/1 - 0s - loss: 4674.1899 - 9ms/epoch - 9ms/step
# Epoch 7/100
# 1/1 - 0s - loss: 4586.2104 - 6ms/epoch - 6ms/step
# Epoch 8/100
# 1/1 - 0s - loss: 4486.4229 - 8ms/epoch - 8ms/step
# Epoch 9/100
# 1/1 - 0s - loss: 4373.1836 - 4ms/epoch - 4ms/step
# Epoch 10/100
# 1/1 - 0s - loss: 4245.6353 - 7ms/epoch - 7ms/step
# Epoch 11/100
# 1/1 - 0s - loss: 4104.1553 - 5ms/epoch - 5ms/step
# Epoch 12/100
# 1/1 - 0s - loss: 3950.6023 - 8ms/epoch - 8ms/step
# Epoch 13/100
# 1/1 - 0s - loss: 3788.4832 - 5ms/epoch - 5ms/step
# Epoch 14/100
# 1/1 - 0s - loss: 3623.4636 - 8ms/epoch - 8ms/step
# Epoch 15/100
# 1/1 - 0s - loss: 3462.9507 - 4ms/epoch - 4ms/step
# Epoch 16/100
# 1/1 - 0s - loss: 3313.7742 - 7ms/epoch - 7ms/step
# Epoch 17/100
# 1/1 - 0s - loss: 3179.5955 - 6ms/epoch - 6ms/step
# Epoch 18/100
# 1/1 - 0s - loss: 3058.3738 - 8ms/epoch - 8ms/step
# Epoch 19/100
# 1/1 - 0s - loss: 2946.1562 - 8ms/epoch - 8ms/step
# Epoch 20/100
# 1/1 - 0s - loss: 2838.4302 - 8ms/epoch - 8ms/step
# Epoch 21/100
# 1/1 - 0s - loss: 2730.6379 - 7ms/epoch - 7ms/step
# Epoch 22/100
# 1/1 - 0s - loss: 2619.5364 - 7ms/epoch - 7ms/step
# Epoch 23/100
# 1/1 - 0s - loss: 2503.9390 - 8ms/epoch - 8ms/step
# Epoch 24/100
# 1/1 - 0s - loss: 2384.7566 - 8ms/epoch - 8ms/step
# Epoch 25/100
# 1/1 - 0s - loss: 2264.1035 - 8ms/epoch - 8ms/step
# Epoch 26/100
# 1/1 - 0s - loss: 2143.9812 - 4ms/epoch - 4ms/step
# Epoch 27/100
# 1/1 - 0s - loss: 2025.4961 - 9ms/epoch - 9ms/step
# Epoch 28/100
# 1/1 - 0s - loss: 1908.9525 - 4ms/epoch - 4ms/step
# Epoch 29/100
# 1/1 - 0s - loss: 1794.1257 - 8ms/epoch - 8ms/step
# Epoch 30/100
# 1/1 - 0s - loss: 1680.6101 - 4ms/epoch - 4ms/step
# Epoch 31/100
# 1/1 - 0s - loss: 1567.9094 - 8ms/epoch - 8ms/step
# Epoch 32/100
# 1/1 - 0s - loss: 1455.4846 - 5ms/epoch - 5ms/step
# Epoch 33/100
# 1/1 - 0s - loss: 1343.0658 - 7ms/epoch - 7ms/step
# Epoch 34/100
# 1/1 - 0s - loss: 1231.1028 - 5ms/epoch - 5ms/step
# Epoch 35/100
# 1/1 - 0s - loss: 1120.7263 - 9ms/epoch - 9ms/step
# Epoch 36/100
# 1/1 - 0s - loss: 1013.0619 - 5ms/epoch - 5ms/step
# Epoch 37/100
# 1/1 - 0s - loss: 908.8665 - 8ms/epoch - 8ms/step
# Epoch 38/100
# 1/1 - 0s - loss: 808.8726 - 5ms/epoch - 5ms/step
# Epoch 39/100
# 1/1 - 0s - loss: 713.8035 - 9ms/epoch - 9ms/step
# Epoch 40/100
# 1/1 - 0s - loss: 624.1130 - 4ms/epoch - 4ms/step
# Epoch 41/100
# 1/1 - 0s - loss: 540.1774 - 7ms/epoch - 7ms/step
# Epoch 42/100
# 1/1 - 0s - loss: 462.4579 - 7ms/epoch - 7ms/step
# Epoch 43/100
# 1/1 - 0s - loss: 391.3846 - 8ms/epoch - 8ms/step
# Epoch 44/100
# 1/1 - 0s - loss: 327.2298 - 5ms/epoch - 5ms/step
# Epoch 45/100
# 1/1 - 0s - loss: 270.0978 - 8ms/epoch - 8ms/step
# Epoch 46/100
# 1/1 - 0s - loss: 219.9736 - 4ms/epoch - 4ms/step
# Epoch 47/100
# 1/1 - 0s - loss: 176.7670 - 9ms/epoch - 9ms/step
# Epoch 48/100
# 1/1 - 0s - loss: 140.3306 - 5ms/epoch - 5ms/step
# Epoch 49/100
# 1/1 - 0s - loss: 110.4558 - 7ms/epoch - 7ms/step
# Epoch 50/100
# 1/1 - 0s - loss: 86.8597 - 7ms/epoch - 7ms/step
# Epoch 51/100
# 1/1 - 0s - loss: 69.1694 - 6ms/epoch - 6ms/step
# Epoch 52/100
# 1/1 - 0s - loss: 56.9120 - 9ms/epoch - 9ms/step
# Epoch 53/100
# 1/1 - 0s - loss: 49.5114 - 6ms/epoch - 6ms/step
# Epoch 54/100
# 1/1 - 0s - loss: 46.2948 - 8ms/epoch - 8ms/step
# Epoch 55/100
# 1/1 - 0s - loss: 46.5089 - 4ms/epoch - 4ms/step
# Epoch 56/100
# 1/1 - 0s - loss: 49.3471 - 10ms/epoch - 10ms/step
# Epoch 57/100
# 1/1 - 0s - loss: 53.9857 - 0s/epoch - 0s/step
# Epoch 58/100
# 1/1 - 0s - loss: 59.6214 - 16ms/epoch - 16ms/step
# Epoch 59/100
# 1/1 - 0s - loss: 65.5206 - 7ms/epoch - 7ms/step
# Epoch 60/100
# 1/1 - 0s - loss: 71.0500 - 8ms/epoch - 8ms/step
# Epoch 61/100
# 1/1 - 0s - loss: 75.7079 - 0s/epoch - 0s/step
# Epoch 62/100
# 1/1 - 0s - loss: 79.1374 - 12ms/epoch - 12ms/step
# Epoch 63/100
# 1/1 - 0s - loss: 81.1277 - 0s/epoch - 0s/step
# Epoch 64/100
# 1/1 - 0s - loss: 81.5994 - 13ms/epoch - 13ms/step
# Epoch 65/100
# 1/1 - 0s - loss: 80.5821 - 5ms/epoch - 5ms/step
# Epoch 66/100
# 1/1 - 0s - loss: 78.1866 - 7ms/epoch - 7ms/step
# Epoch 67/100
# 1/1 - 0s - loss: 74.5816 - 7ms/epoch - 7ms/step
# Epoch 68/100
# 1/1 - 0s - loss: 69.9866 - 6ms/epoch - 6ms/step
# Epoch 69/100
# 1/1 - 0s - loss: 64.6914 - 6ms/epoch - 6ms/step
# Epoch 70/100
# 1/1 - 0s - loss: 59.0936 - 4ms/epoch - 4ms/step
# Epoch 71/100
# 1/1 - 0s - loss: 53.6970 - 8ms/epoch - 8ms/step
# Epoch 72/100
# 1/1 - 0s - loss: 49.0079 - 4ms/epoch - 4ms/step
# Epoch 73/100
# 1/1 - 0s - loss: 45.3519 - 7ms/epoch - 7ms/step
# Epoch 74/100
# 1/1 - 0s - loss: 42.7744 - 9ms/epoch - 9ms/step
# Epoch 75/100
# 1/1 - 0s - loss: 41.1134 - 0s/epoch - 0s/step
# Epoch 76/100
# 1/1 - 0s - loss: 40.1445 - 15ms/epoch - 15ms/step
# Epoch 77/100
# 1/1 - 0s - loss: 39.6703 - 0s/epoch - 0s/step
# Epoch 78/100
# 1/1 - 0s - loss: 39.5407 - 14ms/epoch - 14ms/step
# Epoch 79/100
# 1/1 - 0s - loss: 39.6446 - 5ms/epoch - 5ms/step
# Epoch 80/100
# 1/1 - 0s - loss: 39.8979 - 9ms/epoch - 9ms/step
# Epoch 81/100
# 1/1 - 0s - loss: 40.2350 - 5ms/epoch - 5ms/step
# Epoch 82/100
# 1/1 - 0s - loss: 40.6043 - 8ms/epoch - 8ms/step
# Epoch 83/100
# 1/1 - 0s - loss: 40.9654 - 5ms/epoch - 5ms/step
# Epoch 84/100
# 1/1 - 0s - loss: 41.2880 - 8ms/epoch - 8ms/step
# Epoch 85/100
# 1/1 - 0s - loss: 41.5508 - 5ms/epoch - 5ms/step
# Epoch 86/100
# 1/1 - 0s - loss: 41.7407 - 4ms/epoch - 4ms/step
# Epoch 87/100
# 1/1 - 0s - loss: 41.8518 - 6ms/epoch - 6ms/step
# Epoch 88/100
# 1/1 - 0s - loss: 41.8840 - 0s/epoch - 0s/step
# Epoch 89/100
# 1/1 - 0s - loss: 41.8425 - 15ms/epoch - 15ms/step
# Epoch 90/100
# 1/1 - 0s - loss: 41.7357 - 0s/epoch - 0s/step
# Epoch 91/100
# 1/1 - 0s - loss: 41.5752 - 14ms/epoch - 14ms/step
# Epoch 92/100
# 1/1 - 0s - loss: 41.3734 - 0s/epoch - 0s/step
# Epoch 93/100
# 1/1 - 0s - loss: 41.1439 - 14ms/epoch - 14ms/step
# Epoch 94/100
# 1/1 - 0s - loss: 40.8993 - 5ms/epoch - 5ms/step
# Epoch 95/100
# 1/1 - 0s - loss: 40.6518 - 7ms/epoch - 7ms/step
# Epoch 96/100
# 1/1 - 0s - loss: 40.4114 - 4ms/epoch - 4ms/step
# Epoch 97/100
# 1/1 - 0s - loss: 40.1867 - 7ms/epoch - 7ms/step
# Epoch 98/100
# 1/1 - 0s - loss: 39.9839 - 5ms/epoch - 5ms/step
# Epoch 99/100
# 1/1 - 0s - loss: 39.8071 - 8ms/epoch - 8ms/step
# Epoch 100/100
# 1/1 - 0s - loss: 39.6584 - 7ms/epoch - 7ms/step

# %%
# demonstrate prediction
x_input = array([70,80, 90, 100])
x_input = x_input.reshape((1, n_seq, n_steps, n_features))
yhat = model.predict(x_input, verbose=0)
print(yhat)
# Out:
# [[124.17296]]
