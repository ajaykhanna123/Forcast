# %%
import numpy as np # linear algebra
import pandas as pd # data processing
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('dark')
from datetime import datetime, timedelta

import keras
import tensorflow

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import TimeSeriesSplit

from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# Any results you write to the current directory are saved as output.
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
#load the data
data = pd.read_csv('energy_dataset.csv',
                   index_col=[0],
                   parse_dates=True)

dates = pd.date_range(start='2014-12-31T2300', end='2018-12-31T2200', freq='H')
data.index = pd.DatetimeIndex(dates).tz_localize('UTC').tz_convert('Europe/Madrid')
df = data[['total load actual', 'total load forecast']]

null_vals = df.isnull().sum()
print('Null values in the target column {}'.format(null_vals))
df.head()
df.dropna(inplace=True)
# Out:
# Null values in the target column total load actual      36
# total load forecast     0
# dtype: int64
# C:\Users\Ajay\AppData\Local\Temp\ipykernel_21500\2583871192.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace=True)

# %%
data=df.filter(['total load actual'])[0:1000]
dataset=data.values

# %%
# univariate lstm example
from numpy import array
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense

# split a univariate sequence into samples
def split_sequence(sequence, n_steps):
	X, y = list(), list()
	for i in range(len(sequence)):
		# find the end of this pattern
		end_ix = i + n_steps
		# check if we are beyond the sequence
		if end_ix > len(sequence)-1:
			break
		# gather input and output parts of the pattern
		seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
		X.append(seq_x)
		y.append(seq_y)
	return array(X), array(y)

# define input sequence
raw_seq = [10, 20, 30, 40, 50, 60, 70, 80, 90]
# choose a number of time steps
n_steps = 3
# split into samples
X, y = split_sequence(raw_seq, n_steps)
# reshape from [samples, timesteps] into [samples, timesteps, features]
n_features = 1
X = X.reshape((X.shape[0], X.shape[1], n_features))
# define model
model = Sequential()
model.add(LSTM(50, activation='relu', input_shape=(n_steps, n_features)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')
# fit model
model.fit(X, y, epochs=200, verbose=2)
# Out:
# Epoch 1/200
# 1/1 - 1s - loss: 5229.7749 - 1s/epoch - 1s/step
# Epoch 2/200
# 1/1 - 0s - loss: 5177.1753 - 7ms/epoch - 7ms/step
# Epoch 3/200
# 1/1 - 0s - loss: 5126.8311 - 5ms/epoch - 5ms/step
# Epoch 4/200
# 1/1 - 0s - loss: 5078.6421 - 6ms/epoch - 6ms/step
# Epoch 5/200
# 1/1 - 0s - loss: 5032.5391 - 6ms/epoch - 6ms/step
# Epoch 6/200
# 1/1 - 0s - loss: 4988.4077 - 8ms/epoch - 8ms/step
# Epoch 7/200
# 1/1 - 0s - loss: 4946.1274 - 5ms/epoch - 5ms/step
# Epoch 8/200
# 1/1 - 0s - loss: 4905.5767 - 5ms/epoch - 5ms/step
# Epoch 9/200
# 1/1 - 0s - loss: 4866.6118 - 7ms/epoch - 7ms/step
# Epoch 10/200
# 1/1 - 0s - loss: 4829.0776 - 7ms/epoch - 7ms/step
# Epoch 11/200
# 1/1 - 0s - loss: 4792.8091 - 5ms/epoch - 5ms/step
# Epoch 12/200
# 1/1 - 0s - loss: 4757.6313 - 6ms/epoch - 6ms/step
# Epoch 13/200
# 1/1 - 0s - loss: 4723.3579 - 6ms/epoch - 6ms/step
# Epoch 14/200
# 1/1 - 0s - loss: 4689.7676 - 7ms/epoch - 7ms/step
# Epoch 15/200
# 1/1 - 0s - loss: 4656.2095 - 6ms/epoch - 6ms/step
# Epoch 16/200
# 1/1 - 0s - loss: 4622.8296 - 7ms/epoch - 7ms/step
# Epoch 17/200
# 1/1 - 0s - loss: 4589.4175 - 5ms/epoch - 5ms/step
# Epoch 18/200
# 1/1 - 0s - loss: 4555.7183 - 10ms/epoch - 10ms/step
# Epoch 19/200
# 1/1 - 0s - loss: 4521.4575 - 6ms/epoch - 6ms/step
# Epoch 20/200
# 1/1 - 0s - loss: 4486.3452 - 7ms/epoch - 7ms/step
# Epoch 21/200
# 1/1 - 0s - loss: 4450.0625 - 5ms/epoch - 5ms/step
# Epoch 22/200
# 1/1 - 0s - loss: 4412.2681 - 8ms/epoch - 8ms/step
# Epoch 23/200
# 1/1 - 0s - loss: 4372.5781 - 5ms/epoch - 5ms/step
# Epoch 24/200
# 1/1 - 0s - loss: 4330.5591 - 7ms/epoch - 7ms/step
# Epoch 25/200
# 1/1 - 0s - loss: 4285.7197 - 5ms/epoch - 5ms/step
# Epoch 26/200
# 1/1 - 0s - loss: 4237.5215 - 7ms/epoch - 7ms/step
# Epoch 27/200
# 1/1 - 0s - loss: 4185.3257 - 9ms/epoch - 9ms/step
# Epoch 28/200
# 1/1 - 0s - loss: 4128.3911 - 5ms/epoch - 5ms/step
# Epoch 29/200
# 1/1 - 0s - loss: 4065.8875 - 7ms/epoch - 7ms/step
# Epoch 30/200
# 1/1 - 0s - loss: 3997.0950 - 5ms/epoch - 5ms/step
# Epoch 31/200
# 1/1 - 0s - loss: 3921.4121 - 8ms/epoch - 8ms/step
# Epoch 32/200
# 1/1 - 0s - loss: 3837.3328 - 4ms/epoch - 4ms/step
# Epoch 33/200
# 1/1 - 0s - loss: 3744.0320 - 8ms/epoch - 8ms/step
# Epoch 34/200
# 1/1 - 0s - loss: 3641.2405 - 4ms/epoch - 4ms/step
# Epoch 35/200
# 1/1 - 0s - loss: 3529.2871 - 8ms/epoch - 8ms/step
# Epoch 36/200
# 1/1 - 0s - loss: 3409.3057 - 5ms/epoch - 5ms/step
# Epoch 37/200
# 1/1 - 0s - loss: 3283.0784 - 0s/epoch - 0s/step
# Epoch 38/200
# 1/1 - 0s - loss: 3152.6084 - 5ms/epoch - 5ms/step
# Epoch 39/200
# 1/1 - 0s - loss: 3019.4866 - 7ms/epoch - 7ms/step
# Epoch 40/200
# 1/1 - 0s - loss: 2884.3171 - 8ms/epoch - 8ms/step
# Epoch 41/200
# 1/1 - 0s - loss: 2746.5000 - 7ms/epoch - 7ms/step
# Epoch 42/200
# 1/1 - 0s - loss: 2604.3735 - 8ms/epoch - 8ms/step
# Epoch 43/200
# 1/1 - 0s - loss: 2455.5945 - 4ms/epoch - 4ms/step
# Epoch 44/200
# 1/1 - 0s - loss: 2297.5859 - 7ms/epoch - 7ms/step
# Epoch 45/200
# 1/1 - 0s - loss: 2127.9316 - 6ms/epoch - 6ms/step
# Epoch 46/200
# 1/1 - 0s - loss: 1944.7179 - 6ms/epoch - 6ms/step
# Epoch 47/200
# 1/1 - 0s - loss: 1747.1417 - 5ms/epoch - 5ms/step
# Epoch 48/200
# 1/1 - 0s - loss: 1536.7948 - 7ms/epoch - 7ms/step
# Epoch 49/200
# 1/1 - 0s - loss: 1318.9868 - 6ms/epoch - 6ms/step
# Epoch 50/200
# 1/1 - 0s - loss: 1102.3489 - 0s/epoch - 0s/step
# Epoch 51/200
# 1/1 - 0s - loss: 896.5726 - 15ms/epoch - 15ms/step
# Epoch 52/200
# 1/1 - 0s - loss: 710.0378 - 0s/epoch - 0s/step
# Epoch 53/200
# 1/1 - 0s - loss: 547.8489 - 13ms/epoch - 13ms/step
# Epoch 54/200
# 1/1 - 0s - loss: 411.0233 - 3ms/epoch - 3ms/step
# Epoch 55/200
# 1/1 - 0s - loss: 298.1153 - 9ms/epoch - 9ms/step
# Epoch 56/200
# 1/1 - 0s - loss: 209.3893 - 4ms/epoch - 4ms/step
# Epoch 57/200
# 1/1 - 0s - loss: 150.1036 - 8ms/epoch - 8ms/step
# Epoch 58/200
# 1/1 - 0s - loss: 125.9853 - 771us/epoch - 771us/step
# Epoch 59/200
# 1/1 - 0s - loss: 133.7065 - 12ms/epoch - 12ms/step
# Epoch 60/200
# 1/1 - 0s - loss: 160.4788 - 4ms/epoch - 4ms/step
# Epoch 61/200
# 1/1 - 0s - loss: 193.5711 - 0s/epoch - 0s/step
# Epoch 62/200
# 1/1 - 0s - loss: 224.1767 - 6ms/epoch - 6ms/step
# Epoch 63/200
# 1/1 - 0s - loss: 246.8683 - 0s/epoch - 0s/step
# Epoch 64/200
# 1/1 - 0s - loss: 259.1404 - 14ms/epoch - 14ms/step
# Epoch 65/200
# 1/1 - 0s - loss: 260.8150 - 0s/epoch - 0s/step
# Epoch 66/200
# 1/1 - 0s - loss: 252.9786 - 13ms/epoch - 13ms/step
# Epoch 67/200
# 1/1 - 0s - loss: 237.4839 - 4ms/epoch - 4ms/step
# Epoch 68/200
# 1/1 - 0s - loss: 216.3894 - 7ms/epoch - 7ms/step
# Epoch 69/200
# 1/1 - 0s - loss: 191.9088 - 4ms/epoch - 4ms/step
# Epoch 70/200
# 1/1 - 0s - loss: 166.1108 - 0s/epoch - 0s/step
# Epoch 71/200
# 1/1 - 0s - loss: 141.0108 - 5ms/epoch - 5ms/step
# Epoch 72/200
# 1/1 - 0s - loss: 118.7786 - 0s/epoch - 0s/step
# Epoch 73/200
# 1/1 - 0s - loss: 101.6287 - 12ms/epoch - 12ms/step
# Epoch 74/200
# 1/1 - 0s - loss: 90.9509 - 4ms/epoch - 4ms/step
# Epoch 75/200
# 1/1 - 0s - loss: 86.3685 - 8ms/epoch - 8ms/step
# Epoch 76/200
# 1/1 - 0s - loss: 86.0641 - 4ms/epoch - 4ms/step
# Epoch 77/200
# 1/1 - 0s - loss: 87.9848 - 9ms/epoch - 9ms/step
# Epoch 78/200
# 1/1 - 0s - loss: 90.5759 - 5ms/epoch - 5ms/step
# Epoch 79/200
# 1/1 - 0s - loss: 92.8619 - 0s/epoch - 0s/step
# Epoch 80/200
# 1/1 - 0s - loss: 94.3011 - 5ms/epoch - 5ms/step
# Epoch 81/200
# 1/1 - 0s - loss: 94.6433 - 0s/epoch - 0s/step
# Epoch 82/200
# 1/1 - 0s - loss: 93.8199 - 14ms/epoch - 14ms/step
# Epoch 83/200
# 1/1 - 0s - loss: 91.8857 - 4ms/epoch - 4ms/step
# Epoch 84/200
# 1/1 - 0s - loss: 88.9874 - 8ms/epoch - 8ms/step
# Epoch 85/200
# 1/1 - 0s - loss: 85.3364 - 5ms/epoch - 5ms/step
# Epoch 86/200
# 1/1 - 0s - loss: 81.1893 - 7ms/epoch - 7ms/step
# Epoch 87/200
# 1/1 - 0s - loss: 76.8361 - 4ms/epoch - 4ms/step
# Epoch 88/200
# 1/1 - 0s - loss: 72.5839 - 9ms/epoch - 9ms/step
# Epoch 89/200
# 1/1 - 0s - loss: 68.7355 - 5ms/epoch - 5ms/step
# Epoch 90/200
# 1/1 - 0s - loss: 65.5530 - 0s/epoch - 0s/step
# Epoch 91/200
# 1/1 - 0s - loss: 63.1946 - 6ms/epoch - 6ms/step
# Epoch 92/200
# 1/1 - 0s - loss: 61.6322 - 6ms/epoch - 6ms/step
# Epoch 93/200
# 1/1 - 0s - loss: 60.6029 - 7ms/epoch - 7ms/step
# Epoch 94/200
# 1/1 - 0s - loss: 59.6831 - 7ms/epoch - 7ms/step
# Epoch 95/200
# 1/1 - 0s - loss: 58.4743 - 5ms/epoch - 5ms/step
# Epoch 96/200
# 1/1 - 0s - loss: 56.7509 - 8ms/epoch - 8ms/step
# Epoch 97/200
# 1/1 - 0s - loss: 54.4917 - 7ms/epoch - 7ms/step
# Epoch 98/200
# 1/1 - 0s - loss: 51.8297 - 4ms/epoch - 4ms/step
# Epoch 99/200
# 1/1 - 0s - loss: 48.9682 - 8ms/epoch - 8ms/step
# Epoch 100/200
# 1/1 - 0s - loss: 46.1016 - 6ms/epoch - 6ms/step
# Epoch 101/200
# 1/1 - 0s - loss: 43.3640 - 5ms/epoch - 5ms/step
# Epoch 102/200
# 1/1 - 0s - loss: 40.8149 - 5ms/epoch - 5ms/step
# Epoch 103/200
# 1/1 - 0s - loss: 38.4509 - 5ms/epoch - 5ms/step
# Epoch 104/200
# 1/1 - 0s - loss: 36.2315 - 7ms/epoch - 7ms/step
# Epoch 105/200
# 1/1 - 0s - loss: 34.1074 - 5ms/epoch - 5ms/step
# Epoch 106/200
# 1/1 - 0s - loss: 32.0451 - 8ms/epoch - 8ms/step
# Epoch 107/200
# 1/1 - 0s - loss: 30.0477 - 5ms/epoch - 5ms/step
# Epoch 108/200
# 1/1 - 0s - loss: 28.1689 - 6ms/epoch - 6ms/step
# Epoch 109/200
# 1/1 - 0s - loss: 26.5076 - 4ms/epoch - 4ms/step
# Epoch 110/200
# 1/1 - 0s - loss: 25.1055 - 4ms/epoch - 4ms/step
# Epoch 111/200
# 1/1 - 0s - loss: 23.8219 - 8ms/epoch - 8ms/step
# Epoch 112/200
# 1/1 - 0s - loss: 22.4473 - 4ms/epoch - 4ms/step
# Epoch 113/200
# 1/1 - 0s - loss: 20.9587 - 9ms/epoch - 9ms/step
# Epoch 114/200
# 1/1 - 0s - loss: 19.4779 - 4ms/epoch - 4ms/step
# Epoch 115/200
# 1/1 - 0s - loss: 18.1254 - 9ms/epoch - 9ms/step
# Epoch 116/200
# 1/1 - 0s - loss: 16.9392 - 4ms/epoch - 4ms/step
# Epoch 117/200
# 1/1 - 0s - loss: 15.8827 - 9ms/epoch - 9ms/step
# Epoch 118/200
# 1/1 - 0s - loss: 14.8945 - 6ms/epoch - 6ms/step
# Epoch 119/200
# 1/1 - 0s - loss: 13.9329 - 5ms/epoch - 5ms/step
# Epoch 120/200
# 1/1 - 0s - loss: 13.0017 - 6ms/epoch - 6ms/step
# Epoch 121/200
# 1/1 - 0s - loss: 12.1326 - 0s/epoch - 0s/step
# Epoch 122/200
# 1/1 - 0s - loss: 11.3567 - 13ms/epoch - 13ms/step
# Epoch 123/200
# 1/1 - 0s - loss: 10.6952 - 3ms/epoch - 3ms/step
# Epoch 124/200
# 1/1 - 0s - loss: 10.1240 - 8ms/epoch - 8ms/step
# Epoch 125/200
# 1/1 - 0s - loss: 9.5892 - 5ms/epoch - 5ms/step
# Epoch 126/200
# 1/1 - 0s - loss: 9.0590 - 7ms/epoch - 7ms/step
# Epoch 127/200
# 1/1 - 0s - loss: 8.5492 - 5ms/epoch - 5ms/step
# Epoch 128/200
# 1/1 - 0s - loss: 8.0952 - 8ms/epoch - 8ms/step
# Epoch 129/200
# 1/1 - 0s - loss: 7.7089 - 6ms/epoch - 6ms/step
# Epoch 130/200
# 1/1 - 0s - loss: 7.3751 - 0s/epoch - 0s/step
# Epoch 131/200
# 1/1 - 0s - loss: 7.0665 - 5ms/epoch - 5ms/step
# Epoch 132/200
# 1/1 - 0s - loss: 6.7638 - 5ms/epoch - 5ms/step
# Epoch 133/200
# 1/1 - 0s - loss: 6.4693 - 5ms/epoch - 5ms/step
# Epoch 134/200
# 1/1 - 0s - loss: 6.1887 - 4ms/epoch - 4ms/step
# Epoch 135/200
# 1/1 - 0s - loss: 5.9312 - 6ms/epoch - 6ms/step
# Epoch 136/200
# 1/1 - 0s - loss: 5.6935 - 0s/epoch - 0s/step
# Epoch 137/200
# 1/1 - 0s - loss: 5.4655 - 5ms/epoch - 5ms/step
# Epoch 138/200
# 1/1 - 0s - loss: 5.2358 - 0s/epoch - 0s/step
# Epoch 139/200
# 1/1 - 0s - loss: 5.0017 - 15ms/epoch - 15ms/step
# Epoch 140/200
# 1/1 - 0s - loss: 4.7711 - 6ms/epoch - 6ms/step
# Epoch 141/200
# 1/1 - 0s - loss: 4.5522 - 9ms/epoch - 9ms/step
# Epoch 142/200
# 1/1 - 0s - loss: 4.3470 - 5ms/epoch - 5ms/step
# Epoch 143/200
# 1/1 - 0s - loss: 4.1516 - 8ms/epoch - 8ms/step
# Epoch 144/200
# 1/1 - 0s - loss: 3.9614 - 4ms/epoch - 4ms/step
# Epoch 145/200
# 1/1 - 0s - loss: 3.7752 - 9ms/epoch - 9ms/step
# Epoch 146/200
# 1/1 - 0s - loss: 3.5962 - 4ms/epoch - 4ms/step
# Epoch 147/200
# 1/1 - 0s - loss: 3.4286 - 0s/epoch - 0s/step
# Epoch 148/200
# 1/1 - 0s - loss: 3.2742 - 5ms/epoch - 5ms/step
# Epoch 149/200
# 1/1 - 0s - loss: 3.1316 - 5ms/epoch - 5ms/step
# Epoch 150/200
# 1/1 - 0s - loss: 2.9976 - 5ms/epoch - 5ms/step
# Epoch 151/200
# 1/1 - 0s - loss: 2.8696 - 0s/epoch - 0s/step
# Epoch 152/200
# 1/1 - 0s - loss: 2.7472 - 13ms/epoch - 13ms/step
# Epoch 153/200
# 1/1 - 0s - loss: 2.6313 - 0s/epoch - 0s/step
# Epoch 154/200
# 1/1 - 0s - loss: 2.5227 - 13ms/epoch - 13ms/step
# Epoch 155/200
# 1/1 - 0s - loss: 2.4206 - 0s/epoch - 0s/step
# Epoch 156/200
# 1/1 - 0s - loss: 2.3251 - 0s/epoch - 0s/step
# Epoch 157/200
# 1/1 - 0s - loss: 2.2413 - 5ms/epoch - 5ms/step
# Epoch 158/200
# 1/1 - 0s - loss: 2.1572 - 0s/epoch - 0s/step
# Epoch 159/200
# 1/1 - 0s - loss: 2.0734 - 5ms/epoch - 5ms/step
# Epoch 160/200
# 1/1 - 0s - loss: 1.9917 - 6ms/epoch - 6ms/step
# Epoch 161/200
# 1/1 - 0s - loss: 1.9132 - 6ms/epoch - 6ms/step
# Epoch 162/200
# 1/1 - 0s - loss: 1.8358 - 0s/epoch - 0s/step
# Epoch 163/200
# 1/1 - 0s - loss: 1.7607 - 12ms/epoch - 12ms/step
# Epoch 164/200
# 1/1 - 0s - loss: 1.6884 - 4ms/epoch - 4ms/step
# Epoch 165/200
# 1/1 - 0s - loss: 1.6270 - 0s/epoch - 0s/step
# Epoch 166/200
# 1/1 - 0s - loss: 1.5677 - 3ms/epoch - 3ms/step
# Epoch 167/200
# 1/1 - 0s - loss: 1.5121 - 14ms/epoch - 14ms/step
# Epoch 168/200
# 1/1 - 0s - loss: 1.4578 - 6ms/epoch - 6ms/step
# Epoch 169/200
# 1/1 - 0s - loss: 1.4083 - 8ms/epoch - 8ms/step
# Epoch 170/200
# 1/1 - 0s - loss: 1.3616 - 4ms/epoch - 4ms/step
# Epoch 171/200
# 1/1 - 0s - loss: 1.3164 - 6ms/epoch - 6ms/step
# Epoch 172/200
# 1/1 - 0s - loss: 1.2731 - 5ms/epoch - 5ms/step
# Epoch 173/200
# 1/1 - 0s - loss: 1.2317 - 7ms/epoch - 7ms/step
# Epoch 174/200
# 1/1 - 0s - loss: 1.1923 - 8ms/epoch - 8ms/step
# Epoch 175/200
# 1/1 - 0s - loss: 1.1568 - 7ms/epoch - 7ms/step
# Epoch 176/200
# 1/1 - 0s - loss: 1.1208 - 5ms/epoch - 5ms/step
# Epoch 177/200
# 1/1 - 0s - loss: 1.0882 - 5ms/epoch - 5ms/step
# Epoch 178/200
# 1/1 - 0s - loss: 1.0573 - 7ms/epoch - 7ms/step
# Epoch 179/200
# 1/1 - 0s - loss: 1.0272 - 5ms/epoch - 5ms/step
# Epoch 180/200
# 1/1 - 0s - loss: 0.9978 - 3ms/epoch - 3ms/step
# Epoch 181/200
# 1/1 - 0s - loss: 0.9693 - 6ms/epoch - 6ms/step
# Epoch 182/200
# 1/1 - 0s - loss: 0.9418 - 5ms/epoch - 5ms/step
# Epoch 183/200
# 1/1 - 0s - loss: 0.9156 - 2ms/epoch - 2ms/step
# Epoch 184/200
# 1/1 - 0s - loss: 0.8905 - 0s/epoch - 0s/step
# Epoch 185/200
# 1/1 - 0s - loss: 0.8689 - 16ms/epoch - 16ms/step
# Epoch 186/200
# 1/1 - 0s - loss: 0.8449 - 0s/epoch - 0s/step
# Epoch 187/200
# 1/1 - 0s - loss: 0.8239 - 16ms/epoch - 16ms/step
# Epoch 188/200
# 1/1 - 0s - loss: 0.8070 - 0s/epoch - 0s/step
# Epoch 189/200
# 1/1 - 0s - loss: 0.7868 - 0s/epoch - 0s/step
# Epoch 190/200
# 1/1 - 0s - loss: 0.7647 - 6ms/epoch - 6ms/step
# Epoch 191/200
# 1/1 - 0s - loss: 0.7519 - 6ms/epoch - 6ms/step
# Epoch 192/200
# 1/1 - 0s - loss: 0.7370 - 0s/epoch - 0s/step
# Epoch 193/200
# 1/1 - 0s - loss: 0.7184 - 0s/epoch - 0s/step
# Epoch 194/200
# 1/1 - 0s - loss: 0.7025 - 16ms/epoch - 16ms/step
# Epoch 195/200
# 1/1 - 0s - loss: 0.6898 - 0s/epoch - 0s/step
# Epoch 196/200
# 1/1 - 0s - loss: 0.6726 - 16ms/epoch - 16ms/step
# Epoch 197/200
# 1/1 - 0s - loss: 0.6627 - 0s/epoch - 0s/step
# Epoch 198/200
# 1/1 - 0s - loss: 0.6523 - 0s/epoch - 0s/step
# Epoch 199/200
# 1/1 - 0s - loss: 0.6396 - 16ms/epoch - 16ms/step
# Epoch 200/200
# 1/1 - 0s - loss: 0.6251 - 0s/epoch - 0s/step

# %%
# demonstrate prediction
x_input = array([80, 90, 100])

# %%
x_input = x_input.reshape((1, n_steps, n_features))
yhat = model.predict(x_input, verbose=0)
print(yhat)
# Out:
# [[114.60111]]
